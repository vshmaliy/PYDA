# %% [markdown]
# # Доработка

# %% [markdown]
# ### В первой задаче вы обрабатываете конкретный случай, когда в данных представлено только 3 пользователя (ключа). Ваш алгоритм не универсальный и не будет давать верный результат, если количество пользователей изменится. Просьба доработать реализацию в этом ключе, тут без цикла не обойтись;

# %% [markdown]
# ## Задание 1
# Дана переменная, в которой хранится словарь, содержащий гео-метки для каждого пользователя (пример структуры данных приведен ниже). Вам необходимо написать программу, которая выведет на экран множество уникальных гео-меток всех пользователей.
#
# Пример работы программы:
#
# ```
# ids = {'user1': [213, 213, 213, 15, 213],
#        'user2': [54, 54, 119, 119, 119],
#        'user3': [213, 98, 98, 35]}
# ```
#
# Результат:
# `{98, 35, 15, 213, 54, 119}`

# %%
ids = {'user1': [213, 213, 213, 15, 213], 
       'user2': [54, 54, 119, 119, 119], 
       'user3': [213, 98, 98, 35]}

# %%
geotags =[]
for user in ids.keys():
    for geo in ids[user]:
        geotags.append(geo)
print("Результат:", set(geotags))
# Out:
# Результат: {98, 35, 15, 213, 54, 119}

# %% [markdown]
# ### и во второй задаче ваша реализация жестко привязана к исходным данным. Ваша задача написать универсальный алгоритм, который будет корректно работать на любых данных аналогичной структуры. А что если запросы будут состоять из любого количества слов от 1 до 1000? Вы же не будете вручную прописывать каждый случай (как сейчас). Я бы рекомендовал использовать в качестве результирующей переменной словарь. Ключами бы в нем были варианты количества слов в запросах, а значениями – количество таких запросов. Формировали бы его так же в цикле, проверяли бы наличие текущей длины в ключах и наращивали бы значение на 1.
#
# #### Просьба доработать эти моменты, в остальном все хорошо.

# %% [markdown]
# ## Задание 2
# Дана переменная, в которой хранится список поисковых запросов пользователя (пример структуры данных приведен ниже). Вам необходимо написать программу, которая выведет на экран распределение количества слов в запросах в требуемом виде.
#
# Пример работы программы:
#
# ```
# queries = [
#     'смотреть сериалы онлайн',
#     'новости спорта',
#     'афиша кино',
#     'курс доллара',
#     'сериалы этим летом',
#     'курс по питону',
#     'сериалы про спорт',
# ]
# ```
#
# Результат:
# ```
# Поисковых запросов, содержащих 2 слов(а): 42.86%
# Поисковых запросов, содержащих 3 слов(а): 57.14%
# ```

# %%
queries = [
    'смотреть сериалы онлайн',
    'новости спорта',
    'афиша кино',
    'курс доллара',
    'сериалы этим летом',
    'курс по питону',
    'сериалы про спорт'
]

# %%
d={}
dic={}
for i, k in enumerate(queries):
    d[str(i+1)]=len(k.split(' '))
for l in range((max(d.values()))+1):
    dic[l]=0
for n in dic.keys():
    p=0
    for m in queries:
        if len(m.split(' '))==int(n):
            p+=1
        dic[n]=p
    if dic[n]!=0:
        print(f"Поисковых запросов, содержащих {str(n)} слов(а):, {round(dic[n]/(len(queries))*100,2)},%")
# Out:
# Поисковых запросов, содержащих 2 слов(а):, 42.86,%
# Поисковых запросов, содержащих 3 слов(а):, 57.14,%
